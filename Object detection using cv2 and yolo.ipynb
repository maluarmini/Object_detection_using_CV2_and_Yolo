# %%
import numpy as np
import cv2
import time

from csv import DictWriter

camera = cv2.VideoCapture(0)

h, w = None, None

with open('yoloDados/YoloNames.names') as f:
    labels = [line.strip() for line in f]

network = cv2.dnn.readNetFromDarknet('yoloDados/yolov3.cfg',
                                     'yoloDados/yolov3.weights')

# %%
layers_names_all = network.getLayerNames()

layers_names_output = \
    [layers_names_all[i[0] - 1] for i in network.getUnconnectedOutLayers()]

probability_minimum = 0.5

threshold = 0.3

colours = np.random.randint(0, 255, size=(len(labels), 3), dtype='uint8')

# %%
while True:
    _, frame = camera.read()

    if w is None or h is None:
        h, w = frame.shape[:2]


    blob = cv2.dnn.blobFromImage(frame, 1 / 255.0, (416, 416),
                                 swapRB=True, crop=False)

    network.setInput(blob)  # definindo blob como entrada para a rede
    start = time.time()
    output_from_network = network.forward(layers_names_output)
    end = time.time()

    print('Tempo gasto atual {:.5f} segundos'.format(end - start))

    bounding_boxes = []
    confidences = []
    class_numbers = []

    for result in output_from_network:
        for detected_objects in result:
            scores = detected_objects[5:]
            class_current = np.argmax(scores)
            confidence_current = scores[class_current]

            if confidence_current > probability_minimum:
                box_current = detected_objects[0:4] * np.array([w, h, w, h])
                x_center, y_center, box_width, box_height = box_current
                x_min = int(x_center - (box_width / 2))
                y_min = int(y_center - (box_height / 2))

                
                bounding_boxes.append([x_min, y_min,
                                       int(box_width), int(box_height)])
                confidences.append(float(confidence_current))
                class_numbers.append(class_current)

    results = cv2.dnn.NMSBoxes(bounding_boxes, confidences,
                               probability_minimum, threshold)

    if len(results) > 0:
        for i in results.flatten():
            x_min, y_min = bounding_boxes[i][0], bounding_boxes[i][1]
            box_width, box_height = bounding_boxes[i][2], bounding_boxes[i][3]
            colour_box_current = colours[class_numbers[i]].tolist()
            cv2.rectangle(frame, (x_min, y_min),
                          (x_min + box_width, y_min + box_height),
                          colour_box_current, 2)

            text_box_current = '{}: {:.4f}'.format(labels[int(class_numbers[i])],
                                                   confidences[i])

            cv2.putText(frame, text_box_current, (x_min, y_min - 5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, colour_box_current, 2)

    cv2.namedWindow('YOLO v3 WebCamera', cv2.WINDOW_NORMAL)
    cv2.imshow('YOLO v3 WebCamera', frame)

    if cv2.waitKey(1) & 0xFF == ord('x'):
        break

camera.release()
cv2.destroyAllWindows()
# Out:
# Tempo gasto atual 0.79922 segundos
# Tempo gasto atual 0.47065 segundos
# Tempo gasto atual 0.38057 segundos
# Tempo gasto atual 0.38515 segundos
# Tempo gasto atual 0.41448 segundos
# Tempo gasto atual 0.41905 segundos
# Tempo gasto atual 0.40115 segundos
# Tempo gasto atual 0.38428 segundos
# Tempo gasto atual 0.40968 segundos
# Tempo gasto atual 0.43445 segundos
# Tempo gasto atual 0.38684 segundos
# Tempo gasto atual 0.39139 segundos
# Tempo gasto atual 0.74486 segundos
# Tempo gasto atual 0.86330 segundos
# Tempo gasto atual 0.84370 segundos
# Tempo gasto atual 0.79362 segundos
# Tempo gasto atual 0.77269 segundos
# Tempo gasto atual 0.82278 segundos
# Tempo gasto atual 0.75232 segundos
# Tempo gasto atual 0.72901 segundos
# Tempo gasto atual 0.53295 segundos
# Tempo gasto atual 0.38842 segundos
# Tempo gasto atual 0.38909 segundos
# Tempo gasto atual 0.38567 segundos
# Tempo gasto atual 0.39005 segundos
# Tempo gasto atual 0.39234 segundos
# Tempo gasto atual 0.38910 segundos
# Tempo gasto atual 0.39069 segundos
# Tempo gasto atual 0.37827 segundos
# Tempo gasto atual 0.38935 segundos
# Tempo gasto atual 0.42332 segundos
# Tempo gasto atual 0.72656 segundos
# Tempo gasto atual 0.70252 segundos
# Tempo gasto atual 0.75714 segundos
# Tempo gasto atual 0.70123 segundos
# Tempo gasto atual 0.71235 segundos
# Tempo gasto atual 0.77485 segundos
# Tempo gasto atual 0.71981 segundos
# Tempo gasto atual 0.68603 segundos
# Tempo gasto atual 0.72594 segundos
# Tempo gasto atual 0.71901 segundos
# Tempo gasto atual 0.74799 segundos
# Tempo gasto atual 0.72033 segundos
# Tempo gasto atual 0.72433 segundos
# Tempo gasto atual 0.73753 segundos
# Tempo gasto atual 0.72139 segundos
# Tempo gasto atual 0.73582 segundos
# Tempo gasto atual 0.74134 segundos
# Tempo gasto atual 0.75238 segundos
# Tempo gasto atual 0.72787 segundos
# Tempo gasto atual 0.70630 segundos
# Tempo gasto atual 0.71110 segundos
# Tempo gasto atual 0.72250 segundos
# Tempo gasto atual 0.70763 segundos
# Tempo gasto atual 0.71013 segundos
# Tempo gasto atual 0.72634 segundos
# Tempo gasto atual 0.72575 segundos
# Tempo gasto atual 0.75738 segundos
# Tempo gasto atual 0.71879 segundos
# Tempo gasto atual 0.85473 segundos
# Tempo gasto atual 0.80508 segundos
# Tempo gasto atual 0.72717 segundos
# Tempo gasto atual 0.74250 segundos
# Tempo gasto atual 0.71204 segundos
# Tempo gasto atual 0.70232 segundos
# Tempo gasto atual 0.69197 segundos
# Tempo gasto atual 0.74471 segundos
# Tempo gasto atual 0.72896 segundos
# Tempo gasto atual 0.71791 segundos
# Tempo gasto atual 0.69414 segundos
# Tempo gasto atual 0.75733 segundos
# Tempo gasto atual 0.73514 segundos
# Tempo gasto atual 0.72480 segundos
# Tempo gasto atual 0.71627 segundos
# Tempo gasto atual 0.72051 segundos
# Tempo gasto atual 0.71074 segundos
# Tempo gasto atual 0.70885 segundos
# Tempo gasto atual 0.73139 segundos
# Tempo gasto atual 0.70270 segundos
# Tempo gasto atual 0.71092 segundos
# Tempo gasto atual 0.70847 segundos
# Tempo gasto atual 0.74547 segundos
# Tempo gasto atual 0.72612 segundos
# Tempo gasto atual 0.72467 segundos
# Tempo gasto atual 0.75947 segundos
# Tempo gasto atual 0.71698 segundos
# Tempo gasto atual 0.69606 segundos
# Tempo gasto atual 0.73831 segundos
# Tempo gasto atual 0.71793 segundos
# Tempo gasto atual 0.75724 segundos
# Tempo gasto atual 0.71224 segundos
# Tempo gasto atual 0.73241 segundos
# Tempo gasto atual 0.66491 segundos
# Tempo gasto atual 0.40871 segundos
# Tempo gasto atual 0.39626 segundos
# Tempo gasto atual 0.43606 segundos
# Tempo gasto atual 0.42921 segundos
# Tempo gasto atual 0.46389 segundos
# Tempo gasto atual 0.42888 segundos
# Tempo gasto atual 0.37998 segundos
# Tempo gasto atual 0.42451 segundos
# Tempo gasto atual 0.40786 segundos
# Tempo gasto atual 0.40970 segundos
# Tempo gasto atual 0.77613 segundos
# Tempo gasto atual 0.74343 segundos
# Tempo gasto atual 0.71234 segundos
# Tempo gasto atual 0.72594 segundos
# Tempo gasto atual 0.76058 segundos
# Tempo gasto atual 0.71848 segundos
# Tempo gasto atual 0.74870 segundos
# Tempo gasto atual 0.70545 segundos
# Tempo gasto atual 0.76097 segundos
# Tempo gasto atual 0.73776 segundos
# Tempo gasto atual 0.70652 segundos
# Tempo gasto atual 0.78151 segundos
# Tempo gasto atual 0.69353 segundos
# Tempo gasto atual 0.69118 segundos
# Tempo gasto atual 0.71125 segundos
# Tempo gasto atual 0.77918 segundos
# Tempo gasto atual 0.73711 segundos
# Tempo gasto atual 0.79082 segundos
# Tempo gasto atual 0.75176 segundos
# Tempo gasto atual 0.79426 segundos
# Tempo gasto atual 0.73922 segundos
# Tempo gasto atual 0.80311 segundos
# Tempo gasto atual 0.85793 segundos
# Tempo gasto atual 0.75875 segundos
# Tempo gasto atual 0.72648 segundos
# Tempo gasto atual 0.81520 segundos
# Tempo gasto atual 0.73191 segundos
# Tempo gasto atual 0.74543 segundos
# Tempo gasto atual 0.71694 segundos
# Tempo gasto atual 0.77432 segundos
# Tempo gasto atual 0.72931 segundos
# Tempo gasto atual 0.73840 segundos
# Tempo gasto atual 0.71217 segundos
# Tempo gasto atual 0.75121 segundos
# Tempo gasto atual 0.74372 segundos
# Tempo gasto atual 0.78707 segundos
# Tempo gasto atual 0.74014 segundos
# Tempo gasto atual 0.73214 segundos
# Tempo gasto atual 0.69495 segundos
# Tempo gasto atual 0.39389 segundos
# Tempo gasto atual 0.39327 segundos
# Tempo gasto atual 0.39961 segundos
# Tempo gasto atual 0.39212 segundos
# Tempo gasto atual 0.38700 segundos
# Tempo gasto atual 0.37829 segundos
# Tempo gasto atual 0.40995 segundos
# Tempo gasto atual 0.40963 segundos
# Tempo gasto atual 0.39769 segundos
# Tempo gasto atual 0.40137 segundos
# Tempo gasto atual 0.76270 segundos
# Tempo gasto atual 0.72169 segundos
# Tempo gasto atual 0.71357 segundos
# Tempo gasto atual 0.74354 segundos
# Tempo gasto atual 0.72209 segundos
# Tempo gasto atual 0.86711 segundos
# Tempo gasto atual 0.82413 segundos
# Tempo gasto atual 0.73579 segundos
# Tempo gasto atual 0.77719 segundos
# Tempo gasto atual 0.76823 segundos
# Tempo gasto atual 0.70888 segundos
# Tempo gasto atual 0.43720 segundos
# Tempo gasto atual 0.38462 segundos
# Tempo gasto atual 0.40720 segundos
# Tempo gasto atual 0.38283 segundos
# Tempo gasto atual 0.39834 segundos
# Tempo gasto atual 0.38117 segundos
# Tempo gasto atual 0.38377 segundos
# Tempo gasto atual 0.39426 segundos
# Tempo gasto atual 0.46277 segundos
# Tempo gasto atual 0.39804 segundos
# Tempo gasto atual 0.69099 segundos
# Tempo gasto atual 0.72176 segundos
# Tempo gasto atual 0.70277 segundos
# Tempo gasto atual 0.70064 segundos
# Tempo gasto atual 0.74233 segundos
# Tempo gasto atual 0.69081 segundos
# Tempo gasto atual 0.75380 segundos
# Tempo gasto atual 0.69109 segundos
# Tempo gasto atual 0.72984 segundos
# Tempo gasto atual 0.73186 segundos
# Tempo gasto atual 0.80123 segundos
# Tempo gasto atual 0.80729 segundos
# Tempo gasto atual 0.81141 segundos
# Tempo gasto atual 0.78230 segundos
# Tempo gasto atual 0.77801 segundos
# Tempo gasto atual 0.69744 segundos
# Tempo gasto atual 0.74754 segundos
# Tempo gasto atual 0.70459 segundos
# Tempo gasto atual 0.50046 segundos
# Tempo gasto atual 0.39195 segundos
# Tempo gasto atual 0.39360 segundos
# Tempo gasto atual 0.43371 segundos
# Tempo gasto atual 0.37932 segundos
# Tempo gasto atual 0.40545 segundos
# Tempo gasto atual 0.39837 segundos
# Tempo gasto atual 0.42515 segundos
# Tempo gasto atual 0.41504 segundos
# Tempo gasto atual 0.40239 segundos
# Tempo gasto atual 0.66290 segundos
# Tempo gasto atual 0.73048 segundos
# Tempo gasto atual 0.74267 segundos
# Tempo gasto atual 0.69233 segundos
# Tempo gasto atual 0.68646 segundos
# Tempo gasto atual 0.69754 segundos
# Tempo gasto atual 0.70012 segundos
# Tempo gasto atual 0.90104 segundos
# Tempo gasto atual 0.84190 segundos
# Tempo gasto atual 0.74644 segundos
# Tempo gasto atual 0.70018 segundos
# Tempo gasto atual 0.76065 segundos
# Tempo gasto atual 0.71729 segundos
# Tempo gasto atual 0.71802 segundos
# Tempo gasto atual 0.69713 segundos
# Tempo gasto atual 0.69915 segundos
# Tempo gasto atual 0.72641 segundos
# Tempo gasto atual 0.66668 segundos
# Tempo gasto atual 0.40259 segundos
# Tempo gasto atual 0.41405 segundos
# Tempo gasto atual 0.39087 segundos
# Tempo gasto atual 0.38236 segundos
# Tempo gasto atual 0.39894 segundos
# Tempo gasto atual 0.38526 segundos
# Tempo gasto atual 0.38707 segundos
# Tempo gasto atual 0.39103 segundos
# Tempo gasto atual 0.40021 segundos
# Tempo gasto atual 0.39226 segundos
# Tempo gasto atual 0.73571 segundos
# Tempo gasto atual 0.70619 segundos
# Tempo gasto atual 0.70000 segundos
# Tempo gasto atual 0.71081 segundos
# Tempo gasto atual 0.70801 segundos
# Tempo gasto atual 0.68291 segundos
# Tempo gasto atual 0.66593 segundos
# Tempo gasto atual 0.76747 segundos
# Tempo gasto atual 0.73921 segundos
# Tempo gasto atual 0.71094 segundos
# Tempo gasto atual 0.68310 segundos
# Tempo gasto atual 0.69371 segundos
# Tempo gasto atual 0.45853 segundos
# Tempo gasto atual 0.38020 segundos
# Tempo gasto atual 0.39100 segundos
# Tempo gasto atual 0.47381 segundos
# Tempo gasto atual 0.38990 segundos
# Tempo gasto atual 0.37167 segundos
# Tempo gasto atual 0.39228 segundos
# Tempo gasto atual 0.44763 segundos
# Tempo gasto atual 0.39180 segundos
# Tempo gasto atual 0.38694 segundos
# Tempo gasto atual 0.64985 segundos
# Tempo gasto atual 0.73285 segundos
# Tempo gasto atual 0.69797 segundos
# Tempo gasto atual 0.68947 segundos
# Tempo gasto atual 0.67215 segundos
# Tempo gasto atual 0.70252 segundos
# Tempo gasto atual 0.70379 segundos
# Tempo gasto atual 0.67133 segundos
# Tempo gasto atual 0.68502 segundos
# Tempo gasto atual 0.63863 segundos
# Tempo gasto atual 0.40695 segundos
# Tempo gasto atual 0.39577 segundos
# Tempo gasto atual 0.40292 segundos
# Tempo gasto atual 0.43991 segundos
# Tempo gasto atual 0.40093 segundos
# Tempo gasto atual 0.40952 segundos
# Tempo gasto atual 0.46709 segundos
# Tempo gasto atual 0.39079 segundos
# Tempo gasto atual 0.41099 segundos
# Tempo gasto atual 0.63675 segundos
# Tempo gasto atual 0.72215 segundos
# Tempo gasto atual 0.77356 segundos
# Tempo gasto atual 0.73449 segundos
# Tempo gasto atual 0.73130 segundos
# Tempo gasto atual 0.76844 segundos
# Tempo gasto atual 0.70753 segundos
# Tempo gasto atual 0.73107 segundos
# Tempo gasto atual 0.84629 segundos
# Tempo gasto atual 0.80270 segundos
# Tempo gasto atual 0.75192 segundos
# Tempo gasto atual 0.74614 segundos
# Tempo gasto atual 0.77758 segundos
# Tempo gasto atual 0.70760 segundos
# Tempo gasto atual 0.72816 segundos
# Tempo gasto atual 0.71108 segundos
# Tempo gasto atual 0.71254 segundos
# Tempo gasto atual 0.72665 segundos
# Tempo gasto atual 0.75174 segundos
# Tempo gasto atual 0.71965 segundos
# Tempo gasto atual 0.75365 segundos
# Tempo gasto atual 0.73312 segundos
# Tempo gasto atual 0.73970 segundos
# Tempo gasto atual 0.75985 segundos
# Tempo gasto atual 0.73146 segundos
# Tempo gasto atual 0.70223 segundos
# Tempo gasto atual 0.74067 segundos
# Tempo gasto atual 0.70015 segundos
# Tempo gasto atual 0.71701 segundos
# Tempo gasto atual 0.72979 segundos
# Tempo gasto atual 0.78875 segundos
# Tempo gasto atual 0.74804 segundos
# Tempo gasto atual 0.73108 segundos
# Tempo gasto atual 0.71253 segundos
# Tempo gasto atual 0.74813 segundos
# Tempo gasto atual 0.71058 segundos
# Tempo gasto atual 0.41956 segundos
# Tempo gasto atual 0.38039 segundos
# Tempo gasto atual 0.50007 segundos
# Tempo gasto atual 0.39506 segundos
